# %%
import pandas as pd

# %%
i9=pd.read_csv('i9_12_gen.csv')

# %%
i9.head()
# Out:
#    country  countryCode        date  filterByKeyword filterByRating  \
# 0    India          NaN  2022-08-30              NaN       fiveStar
# 1    India          NaN  2023-01-15              NaN       fiveStar
# 2   Mexico          NaN  2023-07-10              NaN       fiveStar
# 3  Germany          NaN  2024-02-26              NaN       fiveStar
# 4   France          NaN  2024-02-14              NaN       fiveStar
#
#    isVerified  position  product/listPrice  product/price productAsin  ...  \
# 0        True         1                NaN            NaN  B09FXDLX95  ...
# 1       False         2                NaN            NaN  B09FXDLX95  ...
# 2        True         3                NaN            NaN  B09FXDLX95  ...
# 3        True         4                NaN            NaN  B09FXDLX95  ...
# 4        True         5                NaN            NaN  B09FXDLX95  ...
#
#                                    reviewDescription        reviewId  \
# ...

# %%
i9=i9.drop(["countryCode","filterByRating","filterByKeyword","isVerified","position","product/listPrice","productAsin","reviewId","reviewReaction","reviewUrl","reviewedIn","totalCategoryRatings","totalCategoryReviews","date","product/price","reviewCategoryUrl","variantAsin"],axis=1)

# %%
i9
# Out:
#            country  ratingScore  \
# 0            India            5
# 1            India            5
# 2           Mexico            5
# 3          Germany            5
# 4           France            5
# ..             ...          ...
# 127  United States            5
# 128  United States            5
# 129  United States            5
# 130  United States            5
# 131  United States            5
#
#                                      reviewDescription  \
# 0    I brought this processor for my gaming/worksta...
# 1    Was using amd cpu untill now. Cpu died in 2 ye...
# 2    Se siente mucho la diferencia en el cambio de ...
# 3    Ich hab ihn zurückgesendet da ich mittlerweile...
# 4                                                 Bien
# ..                                                 ...
# 127  High price, but high performance. Great proces...
# 128                             This is a good product
# 129  If you want the best. Get a i9 Intel CPU. For ...
# ...

# %%
i9 = i9.dropna(subset=['reviewDescription'])

# %%
model_name="i9 12th Gen"
model_list=[]
for i in range(0,len(i9),1):
  model_list.append(model_name)
i9=i9.drop('variant',axis=1)
i9['Model']=model_list

# %%
i9
# Out:
#            country  ratingScore  \
# 0            India            5
# 1            India            5
# 2           Mexico            5
# 3          Germany            5
# 4           France            5
# ..             ...          ...
# 127  United States            5
# 128  United States            5
# 129  United States            5
# 130  United States            5
# 131  United States            5
#
#                                      reviewDescription  \
# 0    I brought this processor for my gaming/worksta...
# 1    Was using amd cpu untill now. Cpu died in 2 ye...
# 2    Se siente mucho la diferencia en el cambio de ...
# 3    Ich hab ihn zurückgesendet da ich mittlerweile...
# 4                                                 Bien
# ..                                                 ...
# 127  High price, but high performance. Great proces...
# 128                             This is a good product
# 129  If you want the best. Get a i9 Intel CPU. For ...
# ...

# %%
# i7=i7.drop(["reviewImages/0","reviewImages/1"],axis=1)
# i7

# %%
# !pip install langid

# %%
review_list=i9['reviewDescription'].to_list()
len(review_list)
# Out:
# 132

# %%
languages=[]
from langid import classify

for i in review_list:
  for_classify=i
  language,_=classify(for_classify)
  languages.append(language)

# %%
set(languages)
# Out:
# {'de', 'en', 'es', 'fr', 'it', 'ja', 'nl'}

# %%
i9['Langauge']=languages

# %%
i9
# Out:
#            country  ratingScore  \
# 0            India            5
# 1            India            5
# 2           Mexico            5
# 3          Germany            5
# 4           France            5
# ..             ...          ...
# 127  United States            5
# 128  United States            5
# 129  United States            5
# 130  United States            5
# 131  United States            5
#
#                                      reviewDescription  \
# 0    I brought this processor for my gaming/worksta...
# 1    Was using amd cpu untill now. Cpu died in 2 ye...
# 2    Se siente mucho la diferencia en el cambio de ...
# 3    Ich hab ihn zurückgesendet da ich mittlerweile...
# 4                                                 Bien
# ..                                                 ...
# 127  High price, but high performance. Great proces...
# 128                             This is a good product
# 129  If you want the best. Get a i9 Intel CPU. For ...
# ...

# %%
i9 = i9[i9["Langauge"]=='en']

# %%
i9
# Out:
#            country  ratingScore  \
# 0            India            5
# 1            India            5
# 4           France            5
# 5    United States            5
# 6            Japan            5
# ..             ...          ...
# 126  United States            5
# 127  United States            5
# 128  United States            5
# 129  United States            5
# 130  United States            5
#
#                                      reviewDescription  \
# 0    I brought this processor for my gaming/worksta...
# 1    Was using amd cpu untill now. Cpu died in 2 ye...
# 4                                                 Bien
# 5    I recently got my hands on the Intel Core i9-1...
# 6    I purchase this CPU 1 year ago and it cost me ...
# ..                                                 ...
# 126  I had  high hopes for this sucker and it deliv...
# 127  High price, but high performance. Great proces...
# 128                             This is a good product
# ...

# %%
i9=i9.reset_index(drop=True)
i9.index = i9.index + 1
i9
# Out:
#            country  ratingScore  \
# 1            India            5
# 2            India            5
# 3           France            5
# 4    United States            5
# 5            Japan            5
# ..             ...          ...
# 100  United States            5
# 101  United States            5
# 102  United States            5
# 103  United States            5
# 104  United States            5
#
#                                      reviewDescription  \
# 1    I brought this processor for my gaming/worksta...
# 2    Was using amd cpu untill now. Cpu died in 2 ye...
# 3                                                 Bien
# 4    I recently got my hands on the Intel Core i9-1...
# 5    I purchase this CPU 1 year ago and it cost me ...
# ..                                                 ...
# 100  I had  high hopes for this sucker and it deliv...
# 101  High price, but high performance. Great proces...
# 102                             This is a good product
# ...

# %%
i9.to_csv('i9_12.csv',index=False)
